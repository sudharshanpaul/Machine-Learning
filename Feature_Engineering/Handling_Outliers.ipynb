# %% [markdown]
# #### 5 Number Summary And Box Plot

# %%
# Minimum, Maximum, Median, Q1, Q3, IQM

# %%
import numpy as np

# %%
list_marks = [45,32,56,75,89,54,32,89,90,87,67,54,98,99,67,74]
minimum,Q1,median,Q3,maximum = np.quantile(list_marks,[0,0.25,0.50,0.75,1.0])

# %%
minimum,Q1,median,Q3,maximum
# Out:
# (np.float64(32.0),
#  np.float64(54.0),
#  np.float64(70.5),
#  np.float64(89.0),
#  np.float64(99.0))

# %%
IQR = Q3-Q1
print(IQR)
# Out:
# 35.0

# %%
lower_fence = Q1-1.5*(IQR)
higher_fence = Q3+1.5*IQR

# %%
lower_fence,higher_fence
# Out:
# (np.float64(1.5), np.float64(141.5))

# %%
list_marks = [45,32,56,75,89,54,32,89,90,87,67,54,98,99,67,74]

# %%
import seaborn as sns

# %%
sns.boxplot(list_marks)
# Out:
# <Axes: >

# %%
list_marks = [45,32,56,75,89,54,32,89,90,87,67,54,98,99,67,74,150,170,0.14]

# %%
sns.boxplot(list_marks)
# Out:
# <Axes: >
