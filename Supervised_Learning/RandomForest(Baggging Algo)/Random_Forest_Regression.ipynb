# %% [markdown]
# ## User Car Price Prediction

# %% [markdown]
# ### 1. Problem Statement
# - This dataset comprises used cars sold on cardehko.com in India as well as important features of these cars.
# - If user can predict the price of the car based on input features.
# - Prediction results can be used to give new seller the price suggestion based on market condition.

# %% [markdown]
# ### 2. Data Collection
# - The Dataset is collected from scrapping from cardheko webiste
# - The data consists of 13 column and 15411 rows.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import warnings

warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
df = pd.read_csv("Data/cardekho_imputated.csv")
df.head()
# Out:
#    Unnamed: 0       car_name    brand     model  vehicle_age  km_driven  \
# 0           0    Maruti Alto   Maruti      Alto            9     120000
# 1           1  Hyundai Grand  Hyundai     Grand            5      20000
# 2           2    Hyundai i20  Hyundai       i20           11      60000
# 3           3    Maruti Alto   Maruti      Alto            9      37000
# 4           4  Ford Ecosport     Ford  Ecosport            6      30000
#
#   seller_type fuel_type transmission_type  mileage  engine  max_power  seats  \
# 0  Individual    Petrol            Manual    19.70     796      46.30      5
# 1  Individual    Petrol            Manual    18.90    1197      82.00      5
# 2  Individual    Petrol            Manual    17.00    1197      80.00      5
# 3  Individual    Petrol            Manual    20.92     998      67.10      5
# 4      Dealer    Diesel            Manual    22.77    1498      98.59      5
#
#    selling_price
# 0         120000
# 1         550000
# 2         215000
# 3         226000
# 4         570000

# %%
df.shape
# Out:
# (15411, 14)

# %% [markdown]
# ##### Data Cleaning
# **Handling Missing Values**
# - Handling Missing Values
# - Handling Duplicates
# - Check Data Types
# - Understand the Dataset

# %%
## Check Null Values
## Check Features with nam values
df.isnull().sum()
# Out:
# Unnamed: 0           0
# car_name             0
# brand                0
# model                0
# vehicle_age          0
# km_driven            0
# seller_type          0
# fuel_type            0
# transmission_type    0
# mileage              0
# engine               0
# max_power            0
# seats                0
# selling_price        0
# dtype: int64

# %%
## Remove Unnecessary Columns
df.drop(columns=['car_name','brand'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    Unnamed: 0     model  vehicle_age  km_driven seller_type fuel_type  \
# 0           0      Alto            9     120000  Individual    Petrol
# 1           1     Grand            5      20000  Individual    Petrol
# 2           2       i20           11      60000  Individual    Petrol
# 3           3      Alto            9      37000  Individual    Petrol
# 4           4  Ecosport            6      30000      Dealer    Diesel
#
#   transmission_type  mileage  engine  max_power  seats  selling_price
# 0            Manual    19.70     796      46.30      5         120000
# 1            Manual    18.90    1197      82.00      5         550000
# 2            Manual    17.00    1197      80.00      5         215000
# 3            Manual    20.92     998      67.10      5         226000
# 4            Manual    22.77    1498      98.59      5         570000

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df['model'].unique()
# Out:
# array(['Alto', 'Grand', 'i20', 'Ecosport', 'Wagon R', 'i10', 'Venue',
#        'Swift', 'Verna', 'Duster', 'Cooper', 'Ciaz', 'C-Class', 'Innova',
#        'Baleno', 'Swift Dzire', 'Vento', 'Creta', 'City', 'Bolero',
#        'Fortuner', 'KWID', 'Amaze', 'Santro', 'XUV500', 'KUV100', 'Ignis',
#        'RediGO', 'Scorpio', 'Marazzo', 'Aspire', 'Figo', 'Vitara',
#        'Tiago', 'Polo', 'Seltos', 'Celerio', 'GO', '5', 'CR-V',
#        'Endeavour', 'KUV', 'Jazz', '3', 'A4', 'Tigor', 'Ertiga', 'Safari',
#        'Thar', 'Hexa', 'Rover', 'Eeco', 'A6', 'E-Class', 'Q7', 'Z4', '6',
#        'XF', 'X5', 'Hector', 'Civic', 'D-Max', 'Cayenne', 'X1', 'Rapid',
#        'Freestyle', 'Superb', 'Nexon', 'XUV300', 'Dzire VXI', 'S90',
#        'WR-V', 'XL6', 'Triber', 'ES', 'Wrangler', 'Camry', 'Elantra',
#        'Yaris', 'GL-Class', '7', 'S-Presso', 'Dzire LXI', 'Aura', 'XC',
#        'Ghibli', 'Continental', 'CR', 'Kicks', 'S-Class', 'Tucson',
#        'Harrier', 'X3', 'Octavia', 'Compass', 'CLS', 'redi-GO', 'Glanza',
#        'Macan', 'X4', 'Dzire ZXI', 'XC90', 'F-PACE', 'A8', 'MUX',
#        'GTC4Lusso', 'GLS', 'X-Trail', 'XE', 'XC60', 'Panamera', 'Alturas',
#        'Altroz', 'NX', 'Carnival', 'C', 'RX', 'Ghost', 'Quattroporte',
#        'Gurkha'], dtype=object)

# %%
df.columns
# Out:
# Index(['model', 'vehicle_age', 'km_driven', 'seller_type', 'fuel_type',
#        'transmission_type', 'mileage', 'engine', 'max_power', 'seats',
#        'selling_price'],
#       dtype='object')

# %%
## Getting the different Types of Features
num_features = [features for features in df.columns if df[features].dtype!='O']
print("No of Numerical Features: ",len(num_features))
cat_features = [features for features in df.columns if df[features].dtype=='O']
print("No of Categorical Features: ",len(cat_features))
discrete_features = [features for features in num_features if len(df[features].unique())<=25]
print("No of Discrete Features: ",len(discrete_features))
continuous_features = [features for features in num_features if features not in discrete_features]
print("No of Continuous Features: ",len(continuous_features))
# Out:
# No of Numerical Features:  7
# No of Categorical Features:  4
# No of Discrete Features:  2
# No of Continuous Features:  5

# %%
X = df.drop(['selling_price'],axis=1)
y = df['selling_price']

# %%
X.head()
# Out:
#       model  vehicle_age  km_driven seller_type fuel_type transmission_type  \
# 0      Alto            9     120000  Individual    Petrol            Manual
# 1     Grand            5      20000  Individual    Petrol            Manual
# 2       i20           11      60000  Individual    Petrol            Manual
# 3      Alto            9      37000  Individual    Petrol            Manual
# 4  Ecosport            6      30000      Dealer    Diesel            Manual
#
#    mileage  engine  max_power  seats
# 0    19.70     796      46.30      5
# 1    18.90    1197      82.00      5
# 2    17.00    1197      80.00      5
# 3    20.92     998      67.10      5
# 4    22.77    1498      98.59      5

# %%
df['seller_type'].value_counts()
# Out:
# seller_type
# Dealer              9539
# Individual          5699
# Trustmark Dealer     173
# Name: count, dtype: int64

# %%
df['transmission_type'].value_counts()
# Out:
# transmission_type
# Manual       12225
# Automatic     3186
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
X['model'] = le.fit_transform(X['model'])

# %%
# Create column transformer with 3 types of transformers
num_features = X.select_dtypes(exclude='object').columns
onehotcolumns = ['seller_type','fuel_type','transmission_type']



from sklearn.preprocessing import LabelEncoder,OneHotEncoder,StandardScaler
from sklearn.compose import ColumnTransformer

numeric_transformer = StandardScaler()
oh_transformer = OneHotEncoder(drop='first')

preprocessor = ColumnTransformer(
    [
        ("OneHotEncoder",oh_transformer,onehotcolumns),
        ("StandardScaler",numeric_transformer,num_features)
    ],remainder='passthrough'
)

# %%
preprocessor
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('OneHotEncoder', OneHotEncoder(drop='first'),
#                                  ['seller_type', 'fuel_type',
#                                   'transmission_type']),
#                                 ('StandardScaler', StandardScaler(),
#                                  Index(['model', 'vehicle_age', 'km_driven', 'mileage', 'engine', 'max_power',
#        'seats'],
#       dtype='object'))])

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=42)

# %%
X_train = preprocessor.fit_transform(X_train)
X_test = preprocessor.transform(X_test)

# %%
X_test.shape
# Out:
# (3853, 14)

# %% [markdown]
# ### Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
# Creating function for Evaluating the Model
def evaluate_model(true,predicted):
    mae = mean_absolute_error(true,predicted)
    mse = mean_squared_error(true,predicted)
    rmse = np.sqrt(mse)
    r2score = r2_score(true,predicted)
    return mae,mse,r2score,rmse

# %%
## Begenning the model

models = {
    "Linear Regression" : LinearRegression(),
    "Lasso" : Lasso(),
    "Ridge" : Ridge(),
    "k-Nearest Neighbour Regressor": KNeighborsRegressor(),
    "Decision Tree" : DecisionTreeRegressor(),
    "Random Forest" : RandomForestRegressor()
}

for i in range(len(list(models))):
    model = list(models.values())[i]
    model.fit(X_train,y_train)

    ## Make Prediction
    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)

    model_train_mae,model_train_mse,model_train_r2score,model_train_rmse = evaluate_model(y_train,y_train_pred)
    model_test_mae,model_test_mse,model_test_r2score,model_test_rmse = evaluate_model(y_test,y_test_pred)

    print(list(models.keys())[i])

    print("Model Performance for Training set")
    print("- Mean Absolute Error: {:.4f}".format(model_train_mae))
    print("- Mean Squared Error: {:.4f}".format(model_train_mse))
    print("- R2 Score: {:.4f}".format(model_train_r2score))
    print("- Root-Mean Squared Error: {:.4f}".format(model_train_rmse))


    print('------------------------------------------------------------------')

    print("Model Performance for Test set")
    print("- Mean Absolute Error: {:.4f}".format(model_test_mae))
    print("- Mean Squared Error: {:.4f}".format(model_test_mse))
    print("-  R2 Score: {:.4f}".format(model_test_r2score))
    print("- Root-Mean Squared Error: {:.4f}".format(model_test_rmse))
    print("\n")
# Out:
# Linear Regression
# Model Performance for Training set
# - Mean Absolute Error: 266675.1076
# - Mean Squared Error: 304874315292.8461
# - R2 Score: 0.6220
# - Root-Mean Squared Error: 552154.2495
# ------------------------------------------------------------------
# Model Performance for Test set
# - Mean Absolute Error: 284283.4460
# - Mean Squared Error: 270286925822.7529
# -  R2 Score: 0.6525
# - Root-Mean Squared Error: 519891.2635
#
#
# Lasso
# Model Performance for Training set
# - Mean Absolute Error: 266674.0558
# - Mean Squared Error: 304874327627.3900
# - R2 Score: 0.6220
# - Root-Mean Squared Error: 552154.2607
# ------------------------------------------------------------------
# Model Performance for Test set
# - Mean Absolute Error: 284283.8047
# - Mean Squared Error: 270286283692.1716
# -  R2 Score: 0.6525
# - Root-Mean Squared Error: 519890.6459
#
#
# Ridge
# Model Performance for Training set
# - Mean Absolute Error: 266635.7643
# - Mean Squared Error: 304875008338.2686
# - R2 Score: 0.6220
# - Root-Mean Squared Error: 552154.8771
# ------------------------------------------------------------------
# Model Performance for Test set
# - Mean Absolute Error: 284241.5752
# - Mean Squared Error: 270276506373.7183
# -  R2 Score: 0.6525
# - Root-Mean Squared Error: 519881.2426
#
#
# k-Nearest Neighbour Regressor
# Model Performance for Training set
# - Mean Absolute Error: 92072.1059
# - Mean Squared Error: 105670921367.0185
# - R2 Score: 0.8690
# - Root-Mean Squared Error: 325070.6406
# ------------------------------------------------------------------
# Model Performance for Test set
# - Mean Absolute Error: 116730.2686
# - Mean Squared Error: 77378541763.7231
# -  R2 Score: 0.9005
# - Root-Mean Squared Error: 278169.9872
#
#
# Decision Tree
# Model Performance for Training set
# - Mean Absolute Error: 4991.7517
# - Mean Squared Error: 426210181.9807
# - R2 Score: 0.9995
# - Root-Mean Squared Error: 20644.8585
# ------------------------------------------------------------------
# Model Performance for Test set
# - Mean Absolute Error: 129697.9605
# - Mean Squared Error: 91950448540.6934
# -  R2 Score: 0.8818
# - Root-Mean Squared Error: 303233.3236
#
#
# Random Forest
# Model Performance for Training set
# - Mean Absolute Error: 39838.1708
# - Mean Squared Error: 17103970895.7585
# - R2 Score: 0.9788
# - Root-Mean Squared Error: 130782.1505
# ------------------------------------------------------------------
# Model Performance for Test set
# - Mean Absolute Error: 105241.0549
# - Mean Squared Error: 57363303629.6491
# -  R2 Score: 0.9262
# - Root-Mean Squared Error: 239506.3749

# %%
## Here K-Nearest Neighbout and Randomforest are performing goodd.....

# %%
## Initialize few parameters for Hyperparameter Tuning
knn_params = {"n_neighbors":[2,3,10,20,40,50]}
rf_params = {
    "max_depth":[5,18,15,None,10],
    "max_features":[5,7,"auto",8],
    "min_samples_split":[2,8,15,20],
    "n_estimators":[100,200,500,1000]
}

# %%
randomcv_models = [
    ("KNN",KNeighborsRegressor(),knn_params),
    ("RF",RandomForestRegressor(),rf_params)
]

# %%
from sklearn.model_selection import RandomizedSearchCV

model_params = {}
for name,model,params in randomcv_models:
    random = RandomizedSearchCV(estimator=model,
                                param_distributions=params,
                                n_iter=100,
                                cv=3,
                                verbose=2,
                                n_jobs=1)
    
    random.fit(X_train,y_train)
    model_params[name] = random.best_params_

for model_name in model_params:
    print(f"------------------- Best Params for {model_name} --------------")
    print(model_params[model_name])
# Out:
# Fitting 3 folds for each of 6 candidates, totalling 18 fits
# [CV] END ......................................n_neighbors=2; total time=   0.0s
# [CV] END ......................................n_neighbors=2; total time=   0.0s
# [CV] END ......................................n_neighbors=2; total time=   0.0s
# [CV] END ......................................n_neighbors=3; total time=   0.1s
# [CV] END ......................................n_neighbors=3; total time=   0.1s
# [CV] END ......................................n_neighbors=3; total time=   0.4s
# [CV] END .....................................n_neighbors=10; total time=   0.3s
# [CV] END .....................................n_neighbors=10; total time=   0.2s
# [CV] END .....................................n_neighbors=10; total time=   0.2s
# [CV] END .....................................n_neighbors=20; total time=   0.2s
# [CV] END .....................................n_neighbors=20; total time=   0.2s
# [CV] END .....................................n_neighbors=20; total time=   0.2s
# [CV] END .....................................n_neighbors=40; total time=   0.3s
# [CV] END .....................................n_neighbors=40; total time=   0.3s
# [CV] END .....................................n_neighbors=40; total time=   0.4s
# [CV] END .....................................n_neighbors=50; total time=   0.3s
# [CV] END .....................................n_neighbors=50; total time=   0.3s
# [CV] END .....................................n_neighbors=50; total time=   0.4s
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# [CV] END max_depth=10, max_features=auto, min_samples_split=8, n_estimators=500; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_split=8, n_estimators=500; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_split=8, n_estimators=500; total time=   0.0s
# [CV] END max_depth=18, max_features=8, min_samples_split=8, n_estimators=200; total time=   3.7s
# [CV] END max_depth=18, max_features=8, min_samples_split=8, n_estimators=200; total time=   3.8s
# [CV] END max_depth=18, max_features=8, min_samples_split=8, n_estimators=200; total time=   4.9s
# [CV] END max_depth=None, max_features=8, min_samples_split=15, n_estimators=200; total time=   3.3s
# [CV] END max_depth=None, max_features=8, min_samples_split=15, n_estimators=200; total time=   3.0s
# [CV] END max_depth=None, max_features=8, min_samples_split=15, n_estimators=200; total time=   3.1s
# [CV] END max_depth=5, max_features=7, min_samples_split=15, n_estimators=500; total time=   3.4s
# [CV] END max_depth=5, max_features=7, min_samples_split=15, n_estimators=500; total time=   3.4s
# [CV] END max_depth=5, max_features=7, min_samples_split=15, n_estimators=500; total time=   3.4s
# [CV] END max_depth=10, max_features=7, min_samples_split=2, n_estimators=100; total time=   1.1s
# [CV] END max_depth=10, max_features=7, min_samples_split=2, n_estimators=100; total time=   1.1s
# [CV] END max_depth=10, max_features=7, min_samples_split=2, n_estimators=100; total time=   1.1s
# [CV] END max_depth=5, max_features=5, min_samples_split=2, n_estimators=500; total time=   2.8s
# [CV] END max_depth=5, max_features=5, min_samples_split=2, n_estimators=500; total time=   3.4s
# [CV] END max_depth=5, max_features=5, min_samples_split=2, n_estimators=500; total time=   2.9s
# [CV] END max_depth=10, max_features=auto, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END max_depth=10, max_features=7, min_samples_split=20, n_estimators=200; total time=   2.3s
# [CV] END max_depth=10, max_features=7, min_samples_split=20, n_estimators=200; total time=   2.2s
# [CV] END max_depth=10, max_features=7, min_samples_split=20, n_estimators=200; total time=   2.2s
# [CV] END max_depth=15, max_features=5, min_samples_split=20, n_estimators=1000; total time=  11.9s
# [CV] END max_depth=15, max_features=5, min_samples_split=20, n_estimators=1000; total time=  10.7s
# [CV] END max_depth=15, max_features=5, min_samples_split=20, n_estimators=1000; total time=  10.3s
# [CV] END max_depth=18, max_features=5, min_samples_split=8, n_estimators=1000; total time=  12.3s
# [CV] END max_depth=18, max_features=5, min_samples_split=8, n_estimators=1000; total time=  12.3s
# [CV] END max_depth=18, max_features=5, min_samples_split=8, n_estimators=1000; total time=  12.5s
# [CV] END max_depth=10, max_features=5, min_samples_split=8, n_estimators=100; total time=   0.8s
# [CV] END max_depth=10, max_features=5, min_samples_split=8, n_estimators=100; total time=   0.8s
# [CV] END max_depth=10, max_features=5, min_samples_split=8, n_estimators=100; total time=   0.8s
# [CV] END max_depth=18, max_features=5, min_samples_split=2, n_estimators=200; total time=   3.2s
# [CV] END max_depth=18, max_features=5, min_samples_split=2, n_estimators=200; total time=   3.7s
# [CV] END max_depth=18, max_features=5, min_samples_split=2, n_estimators=200; total time=   3.3s
# [CV] END max_depth=5, max_features=8, min_samples_split=20, n_estimators=200; total time=   1.4s
# [CV] END max_depth=5, max_features=8, min_samples_split=20, n_estimators=200; total time=   1.4s
# [CV] END max_depth=5, max_features=8, min_samples_split=20, n_estimators=200; total time=   1.4s
# [CV] END max_depth=5, max_features=7, min_samples_split=15, n_estimators=200; total time=   1.2s
# [CV] END max_depth=5, max_features=7, min_samples_split=15, n_estimators=200; total time=   1.3s
# [CV] END max_depth=5, max_features=7, min_samples_split=15, n_estimators=200; total time=   1.3s
# [CV] END max_depth=None, max_features=5, min_samples_split=15, n_estimators=200; total time=   2.1s
# [CV] END max_depth=None, max_features=5, min_samples_split=15, n_estimators=200; total time=   2.1s
# [CV] END max_depth=None, max_features=5, min_samples_split=15, n_estimators=200; total time=   2.2s
# [CV] END max_depth=10, max_features=8, min_samples_split=20, n_estimators=200; total time=   2.3s
# [CV] END max_depth=10, max_features=8, min_samples_split=20, n_estimators=200; total time=   2.3s
# [CV] END max_depth=10, max_features=8, min_samples_split=20, n_estimators=200; total time=   2.3s
# [CV] END max_depth=None, max_features=8, min_samples_split=20, n_estimators=200; total time=   2.9s
# [CV] END max_depth=None, max_features=8, min_samples_split=20, n_estimators=200; total time=   2.8s
# [CV] END max_depth=None, max_features=8, min_samples_split=20, n_estimators=200; total time=   2.8s
# [CV] END max_depth=None, max_features=auto, min_samples_split=20, n_estimators=500; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_split=20, n_estimators=500; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_split=20, n_estimators=500; total time=   0.0s
# [CV] END max_depth=None, max_features=7, min_samples_split=8, n_estimators=500; total time=   9.4s
# [CV] END max_depth=None, max_features=7, min_samples_split=8, n_estimators=500; total time=   8.0s
# [CV] END max_depth=None, max_features=7, min_samples_split=8, n_estimators=500; total time=   8.1s
# [CV] END max_depth=None, max_features=8, min_samples_split=8, n_estimators=200; total time=   3.5s
# [CV] END max_depth=None, max_features=8, min_samples_split=8, n_estimators=200; total time=   3.5s
# [CV] END max_depth=None, max_features=8, min_samples_split=8, n_estimators=200; total time=   3.5s
# [CV] END max_depth=15, max_features=8, min_samples_split=20, n_estimators=1000; total time=  14.9s
# [CV] END max_depth=15, max_features=8, min_samples_split=20, n_estimators=1000; total time=  14.9s
# [CV] END max_depth=15, max_features=8, min_samples_split=20, n_estimators=1000; total time=  17.5s
# [CV] END max_depth=10, max_features=5, min_samples_split=8, n_estimators=1000; total time=  11.4s
# [CV] END max_depth=10, max_features=5, min_samples_split=8, n_estimators=1000; total time=   9.8s
# [CV] END max_depth=10, max_features=5, min_samples_split=8, n_estimators=1000; total time=  10.2s
# [CV] END max_depth=18, max_features=7, min_samples_split=15, n_estimators=1000; total time=  14.3s
# [CV] END max_depth=18, max_features=7, min_samples_split=15, n_estimators=1000; total time=  14.1s
# [CV] END max_depth=18, max_features=7, min_samples_split=15, n_estimators=1000; total time=  15.6s
# [CV] END max_depth=5, max_features=auto, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END max_depth=5, max_features=auto, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END max_depth=5, max_features=auto, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END max_depth=5, max_features=8, min_samples_split=20, n_estimators=1000; total time=   8.0s
# [CV] END max_depth=5, max_features=8, min_samples_split=20, n_estimators=1000; total time=   8.3s
# [CV] END max_depth=5, max_features=8, min_samples_split=20, n_estimators=1000; total time=   7.6s
# [CV] END max_depth=10, max_features=8, min_samples_split=8, n_estimators=100; total time=   1.2s
# [CV] END max_depth=10, max_features=8, min_samples_split=8, n_estimators=100; total time=   1.1s
# [CV] END max_depth=10, max_features=8, min_samples_split=8, n_estimators=100; total time=   1.1s
# [CV] END max_depth=10, max_features=auto, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END max_depth=18, max_features=7, min_samples_split=15, n_estimators=200; total time=   2.7s
# [CV] END max_depth=18, max_features=7, min_samples_split=15, n_estimators=200; total time=   2.6s
# [CV] END max_depth=18, max_features=7, min_samples_split=15, n_estimators=200; total time=   2.7s
# [CV] END max_depth=None, max_features=auto, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END max_depth=5, max_features=8, min_samples_split=20, n_estimators=500; total time=   3.5s
# [CV] END max_depth=5, max_features=8, min_samples_split=20, n_estimators=500; total time=   3.7s
# [CV] END max_depth=5, max_features=8, min_samples_split=20, n_estimators=500; total time=   4.3s
# [CV] END max_depth=None, max_features=auto, min_samples_split=20, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_split=20, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_split=20, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=5, max_features=7, min_samples_split=15, n_estimators=100; total time=   0.7s
# [CV] END max_depth=5, max_features=7, min_samples_split=15, n_estimators=100; total time=   0.6s
# [CV] END max_depth=5, max_features=7, min_samples_split=15, n_estimators=100; total time=   0.8s
# [CV] END max_depth=5, max_features=7, min_samples_split=20, n_estimators=200; total time=   1.3s
# [CV] END max_depth=5, max_features=7, min_samples_split=20, n_estimators=200; total time=   1.2s
# [CV] END max_depth=5, max_features=7, min_samples_split=20, n_estimators=200; total time=   1.3s
# [CV] END max_depth=None, max_features=7, min_samples_split=15, n_estimators=100; total time=   1.3s
# [CV] END max_depth=None, max_features=7, min_samples_split=15, n_estimators=100; total time=   1.3s
# [CV] END max_depth=None, max_features=7, min_samples_split=15, n_estimators=100; total time=   1.3s
# [CV] END max_depth=10, max_features=5, min_samples_split=8, n_estimators=200; total time=   1.7s
# [CV] END max_depth=10, max_features=5, min_samples_split=8, n_estimators=200; total time=   1.7s
# [CV] END max_depth=10, max_features=5, min_samples_split=8, n_estimators=200; total time=   1.7s
# [CV] END max_depth=15, max_features=auto, min_samples_split=8, n_estimators=500; total time=   0.0s
# [CV] END max_depth=15, max_features=auto, min_samples_split=8, n_estimators=500; total time=   0.0s
# [CV] END max_depth=15, max_features=auto, min_samples_split=8, n_estimators=500; total time=   0.0s
# [CV] END max_depth=None, max_features=5, min_samples_split=20, n_estimators=500; total time=   5.4s
# [CV] END max_depth=None, max_features=5, min_samples_split=20, n_estimators=500; total time=   5.1s
# [CV] END max_depth=None, max_features=5, min_samples_split=20, n_estimators=500; total time=   5.3s
# [CV] END max_depth=18, max_features=7, min_samples_split=8, n_estimators=1000; total time=  15.8s
# [CV] END max_depth=18, max_features=7, min_samples_split=8, n_estimators=1000; total time=  15.1s
# [CV] END max_depth=18, max_features=7, min_samples_split=8, n_estimators=1000; total time=  15.4s
# [CV] END max_depth=10, max_features=7, min_samples_split=15, n_estimators=200; total time=   2.1s
# [CV] END max_depth=10, max_features=7, min_samples_split=15, n_estimators=200; total time=   2.1s
# [CV] END max_depth=10, max_features=7, min_samples_split=15, n_estimators=200; total time=   2.1s
# [CV] END max_depth=15, max_features=5, min_samples_split=8, n_estimators=500; total time=   5.8s
# [CV] END max_depth=15, max_features=5, min_samples_split=8, n_estimators=500; total time=   5.8s
# [CV] END max_depth=15, max_features=5, min_samples_split=8, n_estimators=500; total time=   5.8s
# [CV] END max_depth=10, max_features=8, min_samples_split=20, n_estimators=500; total time=   6.0s
# [CV] END max_depth=10, max_features=8, min_samples_split=20, n_estimators=500; total time=   6.1s
# [CV] END max_depth=10, max_features=8, min_samples_split=20, n_estimators=500; total time=   5.9s
# [CV] END max_depth=15, max_features=7, min_samples_split=2, n_estimators=200; total time=   3.5s
# [CV] END max_depth=15, max_features=7, min_samples_split=2, n_estimators=200; total time=   3.4s
# [CV] END max_depth=15, max_features=7, min_samples_split=2, n_estimators=200; total time=   3.4s
# [CV] END max_depth=15, max_features=auto, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END max_depth=15, max_features=auto, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END max_depth=15, max_features=auto, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END max_depth=5, max_features=8, min_samples_split=15, n_estimators=1000; total time=   7.1s
# [CV] END max_depth=5, max_features=8, min_samples_split=15, n_estimators=1000; total time=   7.1s
# [CV] END max_depth=5, max_features=8, min_samples_split=15, n_estimators=1000; total time=   7.3s
# [CV] END max_depth=15, max_features=5, min_samples_split=2, n_estimators=1000; total time=  14.1s
# [CV] END max_depth=15, max_features=5, min_samples_split=2, n_estimators=1000; total time=  14.3s
# [CV] END max_depth=15, max_features=5, min_samples_split=2, n_estimators=1000; total time=  15.2s
# [CV] END max_depth=5, max_features=auto, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END max_depth=5, max_features=auto, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END max_depth=5, max_features=auto, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END max_depth=18, max_features=7, min_samples_split=20, n_estimators=500; total time=   6.7s
# [CV] END max_depth=18, max_features=7, min_samples_split=20, n_estimators=500; total time=   6.4s
# [CV] END max_depth=18, max_features=7, min_samples_split=20, n_estimators=500; total time=   6.6s
# [CV] END max_depth=10, max_features=auto, min_samples_split=2, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_split=2, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_split=2, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=None, max_features=7, min_samples_split=20, n_estimators=1000; total time=  13.5s
# [CV] END max_depth=None, max_features=7, min_samples_split=20, n_estimators=1000; total time=  13.0s
# [CV] END max_depth=None, max_features=7, min_samples_split=20, n_estimators=1000; total time=  15.4s
# [CV] END max_depth=18, max_features=auto, min_samples_split=20, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=18, max_features=auto, min_samples_split=20, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=18, max_features=auto, min_samples_split=20, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=5, max_features=7, min_samples_split=20, n_estimators=500; total time=   3.3s
# [CV] END max_depth=5, max_features=7, min_samples_split=20, n_estimators=500; total time=   3.2s
# [CV] END max_depth=5, max_features=7, min_samples_split=20, n_estimators=500; total time=   3.2s
# [CV] END max_depth=10, max_features=5, min_samples_split=15, n_estimators=500; total time=   4.3s
# [CV] END max_depth=10, max_features=5, min_samples_split=15, n_estimators=500; total time=   4.2s
# [CV] END max_depth=10, max_features=5, min_samples_split=15, n_estimators=500; total time=   4.2s
# [CV] END max_depth=None, max_features=7, min_samples_split=20, n_estimators=200; total time=   2.5s
# [CV] END max_depth=None, max_features=7, min_samples_split=20, n_estimators=200; total time=   2.6s
# [CV] END max_depth=None, max_features=7, min_samples_split=20, n_estimators=200; total time=   2.5s
# [CV] END max_depth=5, max_features=8, min_samples_split=2, n_estimators=500; total time=   3.5s
# [CV] END max_depth=5, max_features=8, min_samples_split=2, n_estimators=500; total time=   3.5s
# [CV] END max_depth=5, max_features=8, min_samples_split=2, n_estimators=500; total time=   3.5s
# [CV] END max_depth=15, max_features=5, min_samples_split=2, n_estimators=500; total time=   6.9s
# [CV] END max_depth=15, max_features=5, min_samples_split=2, n_estimators=500; total time=   7.1s
# [CV] END max_depth=15, max_features=5, min_samples_split=2, n_estimators=500; total time=   7.0s
# [CV] END max_depth=15, max_features=8, min_samples_split=2, n_estimators=200; total time=   3.9s
# [CV] END max_depth=15, max_features=8, min_samples_split=2, n_estimators=200; total time=   3.8s
# [CV] END max_depth=15, max_features=8, min_samples_split=2, n_estimators=200; total time=   3.8s
# [CV] END max_depth=5, max_features=5, min_samples_split=8, n_estimators=100; total time=   0.5s
# [CV] END max_depth=5, max_features=5, min_samples_split=8, n_estimators=100; total time=   0.5s
# [CV] END max_depth=5, max_features=5, min_samples_split=8, n_estimators=100; total time=   0.5s
# [CV] END max_depth=18, max_features=auto, min_samples_split=8, n_estimators=500; total time=   0.0s
# [CV] END max_depth=18, max_features=auto, min_samples_split=8, n_estimators=500; total time=   0.0s
# [CV] END max_depth=18, max_features=auto, min_samples_split=8, n_estimators=500; total time=   0.0s
# [CV] END max_depth=15, max_features=7, min_samples_split=2, n_estimators=500; total time=  10.3s
# [CV] END max_depth=15, max_features=7, min_samples_split=2, n_estimators=500; total time=  11.4s
# [CV] END max_depth=15, max_features=7, min_samples_split=2, n_estimators=500; total time=   9.0s
# [CV] END max_depth=10, max_features=8, min_samples_split=8, n_estimators=200; total time=   2.5s
# [CV] END max_depth=10, max_features=8, min_samples_split=8, n_estimators=200; total time=   2.4s
# [CV] END max_depth=10, max_features=8, min_samples_split=8, n_estimators=200; total time=   2.6s
# [CV] END max_depth=18, max_features=5, min_samples_split=15, n_estimators=200; total time=   2.2s
# [CV] END max_depth=18, max_features=5, min_samples_split=15, n_estimators=200; total time=   2.2s
# [CV] END max_depth=18, max_features=5, min_samples_split=15, n_estimators=200; total time=   2.2s
# [CV] END max_depth=18, max_features=8, min_samples_split=20, n_estimators=500; total time=   7.5s
# [CV] END max_depth=18, max_features=8, min_samples_split=20, n_estimators=500; total time=   7.2s
# [CV] END max_depth=18, max_features=8, min_samples_split=20, n_estimators=500; total time=   7.1s
# [CV] END max_depth=10, max_features=8, min_samples_split=15, n_estimators=1000; total time=  12.0s
# [CV] END max_depth=10, max_features=8, min_samples_split=15, n_estimators=1000; total time=  12.0s
# [CV] END max_depth=10, max_features=8, min_samples_split=15, n_estimators=1000; total time=  11.9s
# [CV] END max_depth=10, max_features=auto, min_samples_split=15, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_split=15, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_split=15, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=10, max_features=5, min_samples_split=20, n_estimators=1000; total time=   8.5s
# [CV] END max_depth=10, max_features=5, min_samples_split=20, n_estimators=1000; total time=   8.5s
# [CV] END max_depth=10, max_features=5, min_samples_split=20, n_estimators=1000; total time=   8.4s
# [CV] END max_depth=None, max_features=7, min_samples_split=2, n_estimators=100; total time=   2.1s
# [CV] END max_depth=None, max_features=7, min_samples_split=2, n_estimators=100; total time=   2.1s
# [CV] END max_depth=None, max_features=7, min_samples_split=2, n_estimators=100; total time=   2.1s
# [CV] END max_depth=10, max_features=5, min_samples_split=20, n_estimators=500; total time=   4.4s
# [CV] END max_depth=10, max_features=5, min_samples_split=20, n_estimators=500; total time=   4.2s
# [CV] END max_depth=10, max_features=5, min_samples_split=20, n_estimators=500; total time=   4.3s
# [CV] END max_depth=None, max_features=auto, min_samples_split=15, n_estimators=500; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_split=15, n_estimators=500; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_split=15, n_estimators=500; total time=   0.0s
# [CV] END max_depth=5, max_features=5, min_samples_split=2, n_estimators=200; total time=   1.2s
# [CV] END max_depth=5, max_features=5, min_samples_split=2, n_estimators=200; total time=   1.0s
# [CV] END max_depth=5, max_features=5, min_samples_split=2, n_estimators=200; total time=   1.0s
# [CV] END max_depth=18, max_features=5, min_samples_split=20, n_estimators=1000; total time=  10.6s
# [CV] END max_depth=18, max_features=5, min_samples_split=20, n_estimators=1000; total time=  10.4s
# [CV] END max_depth=18, max_features=5, min_samples_split=20, n_estimators=1000; total time=  10.5s
# [CV] END max_depth=15, max_features=8, min_samples_split=8, n_estimators=100; total time=   1.6s
# [CV] END max_depth=15, max_features=8, min_samples_split=8, n_estimators=100; total time=   1.5s
# [CV] END max_depth=15, max_features=8, min_samples_split=8, n_estimators=100; total time=   1.6s
# [CV] END max_depth=15, max_features=7, min_samples_split=20, n_estimators=100; total time=   1.3s
# [CV] END max_depth=15, max_features=7, min_samples_split=20, n_estimators=100; total time=   3.1s
# [CV] END max_depth=15, max_features=7, min_samples_split=20, n_estimators=100; total time=   2.2s
# [CV] END max_depth=10, max_features=7, min_samples_split=15, n_estimators=500; total time=  10.0s
# [CV] END max_depth=10, max_features=7, min_samples_split=15, n_estimators=500; total time=   7.3s
# [CV] END max_depth=10, max_features=7, min_samples_split=15, n_estimators=500; total time=   7.1s
# [CV] END max_depth=10, max_features=7, min_samples_split=2, n_estimators=200; total time=   2.4s
# [CV] END max_depth=10, max_features=7, min_samples_split=2, n_estimators=200; total time=   3.7s
# [CV] END max_depth=10, max_features=7, min_samples_split=2, n_estimators=200; total time=   3.5s
# [CV] END max_depth=15, max_features=8, min_samples_split=2, n_estimators=1000; total time=  23.1s
# [CV] END max_depth=15, max_features=8, min_samples_split=2, n_estimators=1000; total time=  20.9s
# [CV] END max_depth=15, max_features=8, min_samples_split=2, n_estimators=1000; total time=  28.6s
# [CV] END max_depth=18, max_features=auto, min_samples_split=15, n_estimators=100; total time=   0.0s
# [CV] END max_depth=18, max_features=auto, min_samples_split=15, n_estimators=100; total time=   0.0s
# [CV] END max_depth=18, max_features=auto, min_samples_split=15, n_estimators=100; total time=   0.0s
# [CV] END max_depth=18, max_features=8, min_samples_split=15, n_estimators=500; total time=  12.9s
# [CV] END max_depth=18, max_features=8, min_samples_split=15, n_estimators=500; total time=  14.3s
# [CV] END max_depth=18, max_features=8, min_samples_split=15, n_estimators=500; total time=  27.8s
# [CV] END max_depth=18, max_features=7, min_samples_split=20, n_estimators=100; total time=   1.6s
# [CV] END max_depth=18, max_features=7, min_samples_split=20, n_estimators=100; total time=   2.1s
# [CV] END max_depth=18, max_features=7, min_samples_split=20, n_estimators=100; total time=   1.3s
# [CV] END max_depth=10, max_features=8, min_samples_split=8, n_estimators=1000; total time=  14.2s
# [CV] END max_depth=10, max_features=8, min_samples_split=8, n_estimators=1000; total time=  19.4s
# [CV] END max_depth=10, max_features=8, min_samples_split=8, n_estimators=1000; total time=  19.5s
# [CV] END max_depth=10, max_features=auto, min_samples_split=20, n_estimators=200; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_split=20, n_estimators=200; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_split=20, n_estimators=200; total time=   0.0s
# [CV] END max_depth=None, max_features=5, min_samples_split=2, n_estimators=500; total time=  13.3s
# [CV] END max_depth=None, max_features=5, min_samples_split=2, n_estimators=500; total time=  12.1s
# [CV] END max_depth=None, max_features=5, min_samples_split=2, n_estimators=500; total time=  11.0s
# [CV] END max_depth=15, max_features=5, min_samples_split=15, n_estimators=1000; total time=  14.2s
# [CV] END max_depth=15, max_features=5, min_samples_split=15, n_estimators=1000; total time=  10.6s
# [CV] END max_depth=15, max_features=5, min_samples_split=15, n_estimators=1000; total time=  11.4s
# [CV] END max_depth=18, max_features=7, min_samples_split=2, n_estimators=100; total time=   2.0s
# [CV] END max_depth=18, max_features=7, min_samples_split=2, n_estimators=100; total time=   2.0s
# [CV] END max_depth=18, max_features=7, min_samples_split=2, n_estimators=100; total time=   1.9s
# [CV] END max_depth=10, max_features=auto, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END max_depth=None, max_features=5, min_samples_split=2, n_estimators=1000; total time=  22.1s
# [CV] END max_depth=None, max_features=5, min_samples_split=2, n_estimators=1000; total time=  22.2s
# [CV] END max_depth=None, max_features=5, min_samples_split=2, n_estimators=1000; total time=  18.9s
# [CV] END max_depth=18, max_features=5, min_samples_split=2, n_estimators=500; total time=   8.6s
# [CV] END max_depth=18, max_features=5, min_samples_split=2, n_estimators=500; total time=   8.7s
# [CV] END max_depth=18, max_features=5, min_samples_split=2, n_estimators=500; total time=   8.4s
# [CV] END max_depth=15, max_features=8, min_samples_split=20, n_estimators=500; total time=   7.3s
# [CV] END max_depth=15, max_features=8, min_samples_split=20, n_estimators=500; total time=   7.2s
# [CV] END max_depth=15, max_features=8, min_samples_split=20, n_estimators=500; total time=   7.4s
# [CV] END max_depth=None, max_features=7, min_samples_split=15, n_estimators=1000; total time=  14.3s
# [CV] END max_depth=None, max_features=7, min_samples_split=15, n_estimators=1000; total time=  18.9s
# [CV] END max_depth=None, max_features=7, min_samples_split=15, n_estimators=1000; total time=  18.9s
# [CV] END max_depth=18, max_features=auto, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END max_depth=18, max_features=auto, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END max_depth=18, max_features=auto, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END max_depth=10, max_features=7, min_samples_split=20, n_estimators=100; total time=   1.9s
# [CV] END max_depth=10, max_features=7, min_samples_split=20, n_estimators=100; total time=   1.1s
# [CV] END max_depth=10, max_features=7, min_samples_split=20, n_estimators=100; total time=   1.1s
# [CV] END max_depth=10, max_features=5, min_samples_split=15, n_estimators=100; total time=   0.9s
# [CV] END max_depth=10, max_features=5, min_samples_split=15, n_estimators=100; total time=   0.8s
# [CV] END max_depth=10, max_features=5, min_samples_split=15, n_estimators=100; total time=   0.9s
# [CV] END max_depth=15, max_features=8, min_samples_split=2, n_estimators=100; total time=   2.1s
# [CV] END max_depth=15, max_features=8, min_samples_split=2, n_estimators=100; total time=   1.8s
# [CV] END max_depth=15, max_features=8, min_samples_split=2, n_estimators=100; total time=   1.8s
# [CV] END max_depth=18, max_features=7, min_samples_split=2, n_estimators=200; total time=   4.3s
# [CV] END max_depth=18, max_features=7, min_samples_split=2, n_estimators=200; total time=   3.9s
# [CV] END max_depth=18, max_features=7, min_samples_split=2, n_estimators=200; total time=   4.0s
# [CV] END max_depth=10, max_features=8, min_samples_split=20, n_estimators=1000; total time=  12.1s
# [CV] END max_depth=10, max_features=8, min_samples_split=20, n_estimators=1000; total time=  14.3s
# [CV] END max_depth=10, max_features=8, min_samples_split=20, n_estimators=1000; total time=  12.9s
# [CV] END max_depth=18, max_features=5, min_samples_split=15, n_estimators=500; total time=   6.4s
# [CV] END max_depth=18, max_features=5, min_samples_split=15, n_estimators=500; total time=   5.6s
# [CV] END max_depth=18, max_features=5, min_samples_split=15, n_estimators=500; total time=   8.1s
# [CV] END max_depth=None, max_features=5, min_samples_split=15, n_estimators=500; total time=   5.6s
# [CV] END max_depth=None, max_features=5, min_samples_split=15, n_estimators=500; total time=   5.4s
# [CV] END max_depth=None, max_features=5, min_samples_split=15, n_estimators=500; total time=   5.5s
# [CV] END max_depth=15, max_features=8, min_samples_split=8, n_estimators=500; total time=   8.0s
# [CV] END max_depth=15, max_features=8, min_samples_split=8, n_estimators=500; total time=   7.8s
# [CV] END max_depth=15, max_features=8, min_samples_split=8, n_estimators=500; total time=   8.0s
# [CV] END max_depth=15, max_features=7, min_samples_split=2, n_estimators=100; total time=   1.7s
# [CV] END max_depth=15, max_features=7, min_samples_split=2, n_estimators=100; total time=   1.7s
# [CV] END max_depth=15, max_features=7, min_samples_split=2, n_estimators=100; total time=   1.7s
# [CV] END max_depth=None, max_features=8, min_samples_split=15, n_estimators=500; total time=   8.4s
# [CV] END max_depth=None, max_features=8, min_samples_split=15, n_estimators=500; total time=   9.7s
# [CV] END max_depth=None, max_features=8, min_samples_split=15, n_estimators=500; total time=  10.3s
# [CV] END max_depth=10, max_features=5, min_samples_split=2, n_estimators=100; total time=   1.3s
# [CV] END max_depth=10, max_features=5, min_samples_split=2, n_estimators=100; total time=   1.5s
# [CV] END max_depth=10, max_features=5, min_samples_split=2, n_estimators=100; total time=   1.0s
# ------------------- Best Params for KNN --------------
# {'n_neighbors': 2}
# ------------------- Best Params for RF --------------
# {'n_estimators': 100, 'min_samples_split': 2, 'max_features': 7, 'max_depth': None}

# %%
## Begenning the model

models = {
    "k-Nearest Neighbour Regressor": KNeighborsRegressor(n_neighbors=2),
    "Random Forest" : RandomForestRegressor(n_estimators=100,min_samples_split=2,max_features=7,max_depth=None)
}

for i in range(len(list(models))):
    model = list(models.values())[i]
    model.fit(X_train,y_train)

    ## Make Prediction
    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)

    model_train_mae,model_train_mse,model_train_r2score,model_train_rmse = evaluate_model(y_train,y_train_pred)
    model_test_mae,model_test_mse,model_test_r2score,model_test_rmse = evaluate_model(y_test,y_test_pred)

    print(list(models.keys())[i])

    print("Model Performance for Training set")
    print("- Mean Absolute Error: {:.4f}".format(model_train_mae))
    print("- Mean Squared Error: {:.4f}".format(model_train_mse))
    print("- R2 Score: {:.4f}".format(model_train_r2score))
    print("- Root-Mean Squared Error: {:.4f}".format(model_train_rmse))


    print('------------------------------------------------------------------')

    print("Model Performance for Test set")
    print("- Mean Absolute Error: {:.4f}".format(model_test_mae))
    print("- Mean Squared Error: {:.4f}".format(model_test_mse))
    print("-  R2 Score: {:.4f}".format(model_test_r2score))
    print("- Root-Mean Squared Error: {:.4f}".format(model_test_rmse))
    print("\n")
# Out:
# k-Nearest Neighbour Regressor
# Model Performance for Training set
# - Mean Absolute Error: 65304.0751
# - Mean Squared Error: 46855041508.0464
# - R2 Score: 0.9419
# - Root-Mean Squared Error: 216460.2539
# ------------------------------------------------------------------
# Model Performance for Test set
# - Mean Absolute Error: 120407.1827
# - Mean Squared Error: 90860473985.3685
# -  R2 Score: 0.8832
# - Root-Mean Squared Error: 301430.7117
#
#
# Random Forest
# Model Performance for Training set
# - Mean Absolute Error: 38969.3951
# - Mean Squared Error: 14278014517.7775
# - R2 Score: 0.9823
# - Root-Mean Squared Error: 119490.6462
# ------------------------------------------------------------------
# Model Performance for Test set
# - Mean Absolute Error: 102594.2615
# - Mean Squared Error: 53633738889.2089
# -  R2 Score: 0.9310
# - Root-Mean Squared Error: 231589.5915
